# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinwanghdat/Bayes/blob/main/Final_Assignment_Name_Surname.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=1DXUVHxd4t15mfuqMgMCLnsP4jWVI5EWz)
#
# ---
#
# <br>
# © 2022 Copyright The University of New South Wales - CRICOS 00098G
#
# **Authors**: Oscar Perez-Concha and Zhisheng (Sandy) Sa.
#
# **Communications**: If you have any questions, please email Oscar and Sandy at: o.perezconcha@unsw.edu.au and z.sa@unsw.edu.au
#
# **Please use email exclusively for communication with us regarding this assignment.**

# %% [markdown]
# # Final Assignment

# %% [markdown]
# ---

# %% [markdown]
# #####################################################################################
#
# Double-click to write down your name and surname.
#
# **Name and Surname: Kaiyi Wang**
#
# **Honour Pledge** <p>
#
#
# Declaration: <p>
#
#
# I declare that this assessment item is my own work, except where acknowledged, and has not been submitted for academic credit elsewhere or previously, or produced independently of this course (e.g. for a third party such as your place of employment) and acknowledge that the assessor of this item may, for the purpose of assessing this item:
#
# 1. Reproduce this assessment item and provide a copy to another member of the University; and/or
#
# 2. Communicate a copy of this assessment item to a plagiarism checking service (which may then retain a copy of the assessment item on its database for the purpose of future plagiarism checking).
#
# #####################################################################################

# %% [markdown]
# ---
# # 1.  Health Data Science Scenario
#
# ## 1a. Research Question
#
# Our hospital has been very proactive in terms of analysing data of its electronic medical record (EMR). By analysing the data, they have made very interesing discoveries:
#
# 1. They identified that readmitted patients are not only those who were sicker in the first admission, but those who had less support at home after discharge or those patients that did not have a medical follow-up after discharge.
# 2. Readmitted patients experienced high levels of emotional stress.
# 3. Readmitted patients were at much higher risk of acquiring new infections while at hospital.
# 4. Readmissions are highly costly. Patients that were readmitted for the reasons cited above tended to be sicker than they were when they were first admitted and their length of stay was significantly longer than their first admission.
#
# Our hospital has trialed a "specialised unit" that coordinates the patient's discharge. A team of nurses and OTs visit the patient's home after discharge. The frequency of the visits depends upon an assessment made before discharge, but the average number of visits is 5 across the board. Amongst other things, they make sure that the wounds are healing properly, medication is taken, that there is coordination with a GP in place and basic daily activities can be done, such as moving around their home, toilet, cooking, ...
# In addition, the specialised unit regularly contacts the patients via telephone to check that everything is going well. The patients can also contact the specialised unit if they need any help.
#
# This pilot has drastically reduced the number of readmissions.
#
# In addition, the cost of operating the specialised unit was much cheaper than the cost of readmissions.
#
# In terms of budget:
# 1. A day in hospital costs 5,000 dollars per day on average; readmitted patients tend to stay an average of 4 days.
# 2. A home visit of the specialised unit costs 400 dollars; the average number of visits is 5.
# 3. No targeted patients: 0 dollars
#
# Our hospital is now ready to roll out and implement the specialised unit service to all patients at risk for readmission.
# The problem is that a priori, they do not know which patients are at risk of readmission. Thus, they do not know the patients they should be targeting.
#
#
# <b><font color=green>Goal/Research Question: </font>
# 1. The hospital needs a machine learning algorithm to predict which patients should participate in this intervention. The prediction will be done just before discharge. They are hiring you to build this algorithm.
#
# 2. You will need to explain to the hospital managers the performance of your algoritm, so they can make an informed decision whether to use your algorithm or not.

# %% [markdown]
# ---

# %% [markdown]
# ## 1b. Instructions
#
# 1. We are going to deliver one predictive model to predict readmission to hospital within 30 days of discharge.
#
# 2. Check and study the data provided. Read the data dictionary carefully and check again the plots and graphs created in the exercises corresponding to weeks 1, 2 and 3.
#
# 3. Since the data have been already provided by the hospital, we are going to skip the next steps of the health data science workflow (see image below).
#   - Step 3 and substeps 3a,3b,3c,3d,3e: Data Gathering.
#
# 4. Step 4, substep 4a: Data visualization. Visualize the data in your draft, but do not include the graphs in the final submission.
#
# 5. The hospital wants the model to capture as many "readmissions" as posible (true positives) even at the expense of <font color='green'><b> moderately</b> </font> increasing the number of false positives <font color='green'><b>  within reason</b></font> (that is, patients that are not at risk of readmission that are classified as readmission).
#
# 6. Nevertheless, we must take into account that the hospital does not have unlimited resources, so they cannot considered a high number of patients at risk of readmission because the cost of the "specialised unit" would be very high.
#
# 7. You will design several machine learning algorithms, choose one, and give a rationale explaining why you choose that algorithm.
#
#     * Build some predictive models to predict readmission to hospital within 30 days of discharge using:
#         *  'Logistic Regression Classifiers'
#         * 'Random Forest Classifier'.
#
# 8. Use the `classification_report` and confusion matrix metrics to evaluate your models. If you use other metrics, such as the ROC curve, do not include them in the final submission.
#
# 9. <b> Very Important: Justify your decisions and why they were made in the space provided.</b>   Write <b>one or two sentences</b> for each section before each block of Python code with the description of what the blocks do; explanations must be clear; no “sanity checks” (although these checks are encouraged during the construction of the algorithms);
#
# 10. Print clear labels in the printed results and explain in short and concise sentences the steps that you followed.
#
# 11. Comment and document your code, as you will most likely later work in teams developing such algorithms.
#
# 12. Format: Jupyter Notebook.
# 13. Programming Language: Python.
# 14. Platform: Google Colab.
# 15. The assignment will be mark using the rubric provided in the outline
#
# 16. **Submission: Upload the Jupyter Notebook in OpenLearning, in the section provided for that and on your GitHub space. The application wil close at exactly the date and time of the deadline.**
#
# 17. Marks will be deducted if these instructions are not followed.
#
# 18. <b><font color=green>Only the final version of the document must be submitted. </font></b>.
#
# 19. Add your name and surname to the name of this document. For example. `Final-Assignment-Oscar-PerezConcha.ipynb`
#
# 20. Each question is 10 marks, except question 8 that is 20 marks.
#
# 21. If you have any questions, please email Oscar and Sandy at:
# o.perezconcha@unsw.edu.au and z.sa@unsw.edu.au

# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=105SGqeyo8RgLhSO8mN7ZE5OsG0YiLPKt)

# %% [markdown]
# ---

# %%
# check required libraries are installed if not calling system to install
import sys
import subprocess
import pkg_resources

required = {'numpy', 'pandas', 'plotnine', 'matplotlib', 'seaborn', 
            'grid', 'shap', 'scikit-learn'}
installed = {pkg.key for pkg in pkg_resources.working_set}
missing = required - installed

if missing:
    print('Installing: ', missing)
    python = sys.executable
    subprocess.check_call([python, '-m', 'pip', 'install', *missing], stdout=subprocess.DEVNULL)
# delete unwanted variables
del required 
del installed 
del missing
# Out:
# Installing:  {'grid', 'shap'}

# %%
# Mount Google Drive
# We do not need to run this cell if you are not running this notebook in Google Colab

if 'google.colab' in str(get_ipython()):
    from google.colab import drive # import drive from Gogle colab
    root = '/content/drive'     # default location for the drive
    # print(root)                 # print content of ROOT (Optional)
    drive.mount(root)
else:
    print('Not running on CoLab')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Change the project paths and the paths according to where you have placed your files:

# %%
from pathlib import Path

if 'google.colab' in str(get_ipython()):
    # EDIT THE PROJECT PATH IF DIFFERENT WITH YOUR ONE
    project_path = Path(root) / 'MyDrive' / 'HDAT9500' / 'final-assignment'

    # OPTIONAL - set working directory according to your google drive project path
    # import os
    # Change directory to the location defined in project_path
    # os.chdir(project_path)
else:
    project_path = Path()

# %% [markdown]
# ---
# Function to plot the confusion matrix:

# %%
def plot_confusion_matrix(confusion_matrix):
  # visualise the confusion matrix
  labels = ['No', 'Yes']
  ax = plt.subplot()
  sns.heatmap(confusion_matrix, annot = True, fmt = '.0f', ax = ax, cmap = 'viridis')

  # labels, titles and ticks
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix')
  ax.xaxis.set_ticklabels(labels)
  ax.yaxis.set_ticklabels(labels)

# %% [markdown]
# ---
# # Question 1: Docstring
#
# Create a docstring with:
# 1. The final aim of our program (50 words limit).
# 2. The variables and constants that you will use in this exercise (data dictionary). It is expected that you choose informative variable names and document your program (both docstrings and comments).
# 3. Divide the docstring in sections. One section per question.
# ---

# %% [markdown]
# <b> Final aim of our program:</b>
#
# ################################################################################
#
# * This program is aiming to establish a predictive model based on machine learning algorithms to predict
# readmission to hospital within 30 days of discharge.
# * Optimized linear regression or random forest model which captures more true readmission patients is
# recommended, even at a moderate cost of false positive rate.
#
# ################################################################################

# %% [markdown]
# <b> Constants and variables in alphabetical order:</b>
#
# ################################################################################
#
#
# ---
# <b> Aim of this program </b>
#
# * Prepare the tidied dataset for establishing machine learning models.
# * Apply cross validation and grid search approahes to build and optimize Logistic Regression and Random Forest models.
# * Model evaluation and comparison.
# * Further evaluate the final model with SHAP package.
# ---
#
# ---
# <b> Question 2: Data preparation </b>
#
# * `hospital`: the imported hospital dataset for this project
# * `pickle_path`: file path for the hospital data
# * `X`: the features of interest
# * `y`: the outcome of interest: 'YES'-readmission within 30 days, 'NO'-no readmission within 30 days
# * `y_binary`: the binarise data of outcomes: 1 - 'YES', 0 - 'NO'
#
# ---
#
# <b> Question 3: Data separation</b>
#
# * `X_test`: test dataset containing the features of interest
# * `X_train`: training dataset containing the features of interest
# * `y_test`: test dataset containing the outcome of interest
# * `y_train`: training dataset containing the outcome of interest
#
# ---
# <b> Question 4: Training, and hyper-parameter tuning of the Logistic Regression model</b>
# * `C_LR_params`: a list of hyperparameters of C value (regularization strength) for grid search for the logistic regression model
# * `class_weight_LR_params`: a list of hyperparameters of class_weight for grid search for the logistic regression model
# * `grid_search_LR`: exhaustive grid search over specified parameter values for an estimator (Logistic Regression classifier for this project).
# * `Log_Reg`: the Logistic Regression classifier
# * `param_grid_LR`: a set of the all hyperparameter lists for grid search
# * `penalty_LR_params`: a list of hyperparameters of penalties ('11' for Lasso and 'l2' for Ridge) for grid search for the logistic regression model
# * `pipe`: a pipeline for grid search, including 'Transform' (standard scaler for the data) and 'Estimator' (Logistic Regression classifier for this project)
# * `scaler`: a scaler to standardize the dummy variables
#
# ---
#
# <b>Question 5: Evaluation of the Logistic Regression model on the training and test sets</b>
#
# * `confusion_LR_test`: confusion matrix derived from `y_test` and `y_pred_LR_test` for the logistic regression model `grid_search_LR` evaluated on the test set.
# * `labels`: a list of outcome label, including 'yes' and 'no'
# * `y_pred_LR_test`: a predicted list of outcomes by the optimized Logistic Regression model
#
# ---
#
# <b>Question 6: Training, and hyper-parameter tuning of the Random Forest model </b>
# * `class_weight_RF_params`: a list of hyperparameters of class_weight for grid search for the Random Forest model
# * `grid_search_RF`: exhaustive grid search over specified parameter values for an estimator (Random Forest classifier for this project)
# * `max_features_RF_params`: a list of hyperparameters of max_features (maximum features to consider when looking for the best split) for grid search for the Random Forest model
# * `min_samples_split_RF_params`: a list of hyperparameters of max_features (The minimum number of samples required to split an internal node) for grid search for the Random Forest model
# * `n_estimators_RF_params`: a list of hyperparameters of n_estimators (number of trees) for grid search for the Random Forest model
# * `param_grid_RF`: a set of the all hyperparameter lists for grid search
# * `pipe_Random_Forest`: a pipeline for grid search, including 'Transform' (standard scaler for the data) and 'Estimator' (Random Forest classifier for this project)
# * `Random_Forest`: the Random Forest classifier
#
#
# ---
#
# <b>Question 7: Evaluation of the Random Forest model on the training and test sets.</b>
#
# * `confusion_RF_test`: confusion matrix derived from `y_test` and `y_pred_RF_test` for the random forest model `grid_search_RF` evaluated on the test set.
# * `y_pred_RF_test`: a predicted list of outcomes by the optimized Random Forest model
#
# ---
#
# <b>Question 9: Evaluation of the Random Forest model on the training and test sets.</b>
#
# * `optimized_RF`: the optimized Random Forest model with the best scores by grid search with cross validation
# * `explainer_RF`: a explainer for the output of Random Forest model using Tree SHAP algorithms
# * `shap_values_Model_train`: Estimate the SHAP values for the training set.
#
# ---
#
# ################################################################################

# %% [markdown]
# ---

# %% [markdown]
# ---
# # Package Loading Section
#
# ---

# %%
# Load the relevant Python packages for this assignment
# packages for data management
import pickle
import numpy as np
import pandas as pd
# packages for spliting data 
from sklearn.model_selection import train_test_split
# packages for Logistic regression
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline 
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import GridSearchCV
# packages for model evaluation
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
import seaborn as sns
import matplotlib.pyplot as plt 
# packages for Random Forest 
from sklearn.ensemble import RandomForestClassifier
# package for further investigation of the preferred model
import shap

# %% [markdown]
# ---
# # Question 2: Read and check the `pickle` provided. Prepare the data so they can be used by the algorithms that you are going to create.
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?-75 words limit:</b>
#
#
# ################################################################################
#
# 1. In this section, the hospital data is firstly imported for preliminarily check and visualisation (not included in this file).
# A decision has been made to drop `admission_id` and `patient_id` which are just identifiers and not related to model prediction.
# 3. Subsets are then created, one containing the features of interest, the other containing the outcome `readmission` which is further binarised for building the ML models.
#
#
# ################################################################################

# %%
# Python code here (15 lines limit)
print('Health Data Science Workflow: 4b')
print('This step is to clean the data, and prepare the dataset for machine learning.')
# Import and open data
pickle_path = project_path/'data'/'hospital_data_final_assignment.pickle'
with open(pickle_path, 'rb') as data:
    hospital = pickle.load(data)
# Drop ID variables
hospital = hospital.drop(['admission_id', 'patient_id'], axis = 1)
# X: the columns/features of interest
X = hospital.drop(['readmission'], axis = 1)
# y: the outcome of the ML algorithms, YES-readmission within 30 days, NO-no readmission within 30 days
y = hospital['readmission'].values
# binarise the y 
y_binary = [0 if x=='no' else 1 for x in y]
# Out:
# Health Data Science Workflow: 4b
# This step is to clean the data, and prepare the dataset for machine learning.

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 3: Divide the data into 80% training, 20% test, random seed of 42. Set the other hyper-parameters as you consider appropriate
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?-75 words limit:</b>
#
#
# ################################################################################
#
# 1. In this section, the previous subsets are divided into 80% training set(`X_train`, `y_train`), 20% test set(`X_test`, `y_test`), with the random seed of 42 as required.
# 2. According to the Exploratory Data Analysis, the dataset is imbalanced (17.2% with 'readmission' vs 82.8% without 'readmission'). As a result, "stratify=y" is added to the function to ensure the same proportion of `readmission` in both training and test sets.
#
#
# ################################################################################

# %%
# Python code here (2 lines limit, and 1 cell limit)
print('Health Data Science Workflow: 4b. This step is to separate the data into training and testing subsets.')
# Split the dataset as required
X_train, X_test, y_train, y_test = train_test_split(X, y_binary, test_size = 0.2, train_size = 0.8, stratify = y, random_state = 42)
# Out:
# Health Data Science Workflow: 4b. This step is to separate the data into training and testing subsets.

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 4: Training, and hyper-parameter tuning of the Logistic Regression model.
#
# Hyper-parameters:
#
# - `C` values: 10, 100.
# - `class_weight`: only two pairs. Choose one of these two combinations and explain why.
#
#     * A weight of (80% for class 1, 20% for class 0) and (70% for class 1, 30% for class 0)
#     * A weight of (80% for class 0, 20% for class 1) and (70% for class 0, 30% for class 1).
#
# - `penalty` values: l1, l2.
# - 3-fold cross-validation for the grid search.
# - `f1` as the score to choose the best model in the grid search.
# - `n_jobs`=-1.
# - do not include the heatmaps in the final submission.
# - do not change these hyper-parameters,
# - keep the remaining set of hyper-parameters in the default state.
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?-75 words limit:</b>
#
#
# ################################################################################
#
# 1. In order to optimize the Logisitic Regression model, in this section, grid search with cross-validation framework based on F1 score performance is built for hyper-parameters tuning.
# 2. Different hyper-parameters including class-weight, C values, penlties are considered. A pipeline includes a standard scaler and and Logistic Regression classifier is also built in assisting the GridSearchCV function.
#
#
# ################################################################################
#
#
# NB: The selection of `class_weight` explanation:
# 1. According to the EDA, this dataset is imbalanced, data labelled as 'No' (class 0) is more than the ones labelled as 'Yes' (class 1)significantly (57348 vs 11919).
# 2. In order to balance data, a justification is made to balance the dataset using `class_weight` hyper-parameter. As a result, we have to increase the weight of class 1, and penalise the weight of class 0. That is, for this project, we choose
#     * A weight of (80% for class 1, 20% for class 0) and (70% for class 1, 30% for class 0)

# %%
# Python code here (15 lines limit, and 2 cells limit)
print('Health Data Science Workflow: 5b & 6b')
print('This step is to design a Logistic Regression algorithm for prediction hospital readmission, \nas well as a grid search with cross validation for hyperparameter tuning.')
      
# Define the standard scaler
scaler = StandardScaler()
# Create the hyperparameters sets for gird search
class_weight_LR_params = [{0:0.2, 1:0.8}, {0:0.3, 1:0.7}]
C_LR_params = [10, 100]
penalty_LR_params = ['l1', 'l2']
param_grid_LR = {'Estimator__C': C_LR_params, 
              'Estimator__penalty': penalty_LR_params, 
              'Estimator__class_weight' : class_weight_LR_params}
# Define the Logistic Regression classifier
Log_Reg = LogisticRegression(solver='liblinear')
# Create a pipeline for grid search
pipe = Pipeline([('Transform', scaler), ('Estimator', Log_Reg)])
# Create a grid search with cross validation framework
grid_search_LR = GridSearchCV(pipe, param_grid_LR, cv = 3, scoring='f1', n_jobs=-1)
# Out:
# Health Data Science Workflow: 5b & 6b
# This step is to design a Logistic Regression algorithm for prediction hospital readmission,
# as well as a grid search with cross validation for hyperparameter tuning.

# %% [markdown]
# ################################################################################
#
# This section is to fit the grid_search with cross-validation framework to the training dataset and train models. The best performed combination of hyper-parameters is selected and fitted a new model.
#
# ################################################################################

# %%
print('Health Data Science Workflow: 6a')
print('This step is to fit the Logistic Regression algorithm to the training dataset and build the model.')
# Apply the grid search - cross-validation algorithm and train data
grid_search_LR.fit(X_train, y_train)
# Out:
# Health Data Science Workflow: 6a
# This step is to fit the Logistic Regression algorithm to the training dataset and build the model.
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('Transform', StandardScaler()),
#                                        ('Estimator',
#                                         LogisticRegression(solver='liblinear'))]),
#              n_jobs=-1,
#              param_grid={'Estimator__C': [10, 100],
#                          'Estimator__class_weight': [{0: 0.2, 1: 0.8},
#                                                      {0: 0.3, 1: 0.7}],
#                          'Estimator__penalty': ['l1', 'l2']},
#              scoring='f1')

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 5: Evaluation of the Logistic Regression model on the training and test sets. Use the function `plot_confusion_matrix(confusion_matrix)` provided above.
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?-75 words limit:</b>
#
#
# ################################################################################
#
# The first section of the evaluation of the Logistic Regression Model is to predict in the training set, in order to justify wheter the model is overfitted.
#
#
# ################################################################################

# %%
# Python code here (10 lines limit, and 2 cells limit)
print('Health Data Science Workflow: 7a')
print('These steps are to evaluate the model with the testing dataset.')
# predict in the training set to see if the model is overfitted
y_pred_grid_search_training_set= grid_search_LR.predict(X_train)
print("F1 on training set: {:.2f}".format(f1_score(y_train, y_pred_grid_search_training_set)))
# Out:
# Health Data Science Workflow: 7a
# These steps are to evaluate the model with the testing dataset.
# F1 on training set: 0.93

# %% [markdown]
# ################################################################################
#
# The next section is to predict the outcome on test set. Classification report and confusion matrix are produced and visualized.
#
#
# ################################################################################

# %%
# Applied the Logistic Regression Model to the testing dataset and make prediction
y_pred_LR_test = grid_search_LR.predict(X_test)
# Generate and print the classification report for model evaluation
labels = {'No', 'Yes'}
print(classification_report(y_test, y_pred_LR_test, target_names=labels))

# Generate and visualize the Confusion matrix
confusion_LR_test = confusion_matrix(y_test, y_pred_LR_test)
plot_confusion_matrix(confusion_LR_test)
# Out:
#               precision    recall  f1-score   support
#
#          Yes       0.99      0.98      0.98     11470
#           No       0.90      0.96      0.93      2384
#
#     accuracy                           0.97     13854
#    macro avg       0.94      0.97      0.96     13854
# weighted avg       0.98      0.97      0.97     13854

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 6: Training, and hyper-parameter tuning of the Random Forest model.
#
# Fixed hyper-parameters (do not change the values of these hyper-parameters):
#
# - `n_estimators`: 150, 200
# - `class_weight`: Only two pairs. Choose one of these two combinations and explain why.
# 1. A weight of (80% for class 1, 20% for class 0) and (70% for class 1, 30% for class 0)
# 2.  A weight of (80% for class 0, 20% for class 1) and (70% for class 0, 30% for class 1).
# - 3-fold cross-validation for the grid search.
# - `f1` as the score to choose the best model in the grid search.
# - `n_jobs`=-1
# - do not include the heatmaps in the final submission
#
# Other hyper-parameters:
#
# - `max_features`: 20, 30
# - `min_samples_split`: 20, 25
# - you can change the previous hyper-parameters (`max_features` and `min_samples_split`) or add other hyper-parameters if you wish. An explanation must be given to why you made that decision.
#
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?-75 words lilmit:</b>
#
#
# ################################################################################
#
# 1. Similar to previous section, when building Random Forest model, grid search with cross-validation framework based on F1 score performance framework is also use
# 2. Different hyper-parameters are considered. A pipeline includes a standard scaler and and Random Forest classifier is also built in assisting the GridSearchCV function.
#
# ################################################################################

# %%
# Python code here (15 lines limit, and 2 cells limit)
print('Health Data Science Workflow: 5b & 6b')
print('This step is to design a Random Forest algorithm for prediction hospital readmission, \nas well as a grid search with cross validation for hyperparameter tuning.')
# Create the hyperparameters sets for gird search
n_estimators_RF_params = [150, 200]
class_weight_RF_params = [{0:0.2, 1:0.8}, {0:0.3, 1:0.7}]
max_features_RF_params = [20, 30]
min_samples_split_RF_params = [20, 25]
param_grid_RF = {'Estimator__n_estimators':n_estimators_RF_params, 
              'Estimator__max_features':max_features_RF_params, 
              'Estimator__class_weight': class_weight_RF_params, 
              'Estimator__min_samples_split':min_samples_split_RF_params}

# Define the Logistic Regression classifier
Random_Forest = RandomForestClassifier()
# Create a pipeline for grid search
pipe_Random_Forest = Pipeline([('Transform', scaler), ('Estimator', Random_Forest)])
# Create a grid search with cross validation framework
grid_search_RF = GridSearchCV(pipe_Random_Forest, param_grid_RF, cv = 3, scoring='f1', n_jobs=-1)
# Out:
# Health Data Science Workflow: 5b & 6b
# This step is to design a Random Forest algorithm for prediction hospital readmission,
# as well as a grid search with cross validation for hyperparameter tuning.

# %% [markdown]
# ################################################################################
#
# This section is to fit the grid_search with cross-validation framework to the training dataset and train models. The best performed combination of hyper-parameters is selected and fitted a new model.
#
# ################################################################################

# %%
print('Health Data Science Workflow: 6a')
print('This step is to fit the Random Forest algorithm to the training dataset and build the model.')
# Apply the grid search - cross-validation algorithm and train data
grid_search_RF.fit(X_train, y_train)
# Out:
# Health Data Science Workflow: 6a
# This step is to fit the Random Forest algorithm to the training dataset and build the model.
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('Transform', StandardScaler()),
#                                        ('Estimator',
#                                         RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid={'Estimator__class_weight': [{0: 0.2, 1: 0.8},
#                                                      {0: 0.3, 1: 0.7}],
#                          'Estimator__max_features': [20, 30],
#                          'Estimator__min_samples_split': [20, 25],
#                          'Estimator__n_estimators': [150, 200]},
#              scoring='f1')

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 7: Evaluation of the Random Forest model on the training and test sets. Use the function `plot_confusion_matrix(confusion_matrix)` provided above.
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?-50 words limit:</b>
#
# ################################################################################
#
# The first section of the evaluation of the Random Forest Model is to predict in the training set, in order to justify wheter the model is overfitted.
#
#
# ################################################################################

# %%
# Python code here (10 lines limit, and 2 cells limit)
print('Health Data Science Workflow: 7a')
print('This step is to evaluate the model in the training dataset.')
# predict in the training set to see if the model is overfitted
y_pred_grid_search_training_set_RF = grid_search_RF.predict(X_train)
print("F1 on training set: {:.2f}".format(f1_score(y_train, y_pred_grid_search_training_set_RF)))
# Out:
# Health Data Science Workflow: 7a
# This step is to evaluate the model in the training dataset.
# F1 on training set: 0.97

# %% [markdown]
# ################################################################################
#
# The next section is to predict the outcome on test set. Classification report and confusion matrix are produced and visualized.
#
#
# ################################################################################

# %%
print('Health Data Science Workflow: 7b')
print('This step is to evaluate the model in the test dataset.')
# Applied the Random Forest Model to the testing dataset and make prediction
y_pred_RF_test = grid_search_RF.predict(X_test)
# Generate and print the classification report for model evaluation
print(classification_report(y_test, y_pred_RF_test, target_names=labels))
# Generate and visualize the Confusion matrix
confusion_RF_test = confusion_matrix(y_test, y_pred_RF_test)
plot_confusion_matrix(confusion_RF_test)
# Out:
# Health Data Science Workflow: 7b
# This step is to evaluate the model in the test dataset.
#               precision    recall  f1-score   support
#
#          Yes       0.99      0.98      0.99     11470
#           No       0.92      0.97      0.94      2384
#
#     accuracy                           0.98     13854
#    macro avg       0.96      0.98      0.97     13854
# weighted avg       0.98      0.98      0.98     13854

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 8: Based on the research questions and the instructions; What model would you choose if any? Would you deploy this model?  - 300 words limit.
# ---

# %% [markdown]
# <b> 300 words limit </b>
#
# ################################################################################
#
# (double-click here)
#
#
# ################################################################################

# %%
# Python code here (10 lines limit, and 2 cells limit)

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 9: Use SHAP for the final model and give some explanation of what you observe. If you haven't chosen any model in question 8, choose the best model according to the evaluation metrics. Comment the results.
# ---

# %% [markdown]
# <b> Explanation of what you observe - 100 words limit:</b>
#
# ################################################################################
#
# The Random Forest model has been chosen for interpretation by SHAP Tree Explainer. The features that affect the RF model prediction most for hospital “readmission” include the length of hospital stay, admission from Emergency, number of medications administrated, and number of outpatients visits yearly. The feature ‘los’ (length of stay) is found to be the most significant influential factor that contributes to the prediction result. This evidence is also consistent with another epidemiology report [1], which indicates that a higher risk of readmission may be associated with more complex patients with a long hospital stay.
#
#
# Reference
# 1.	Rachoin JS, Aplin KS, Gandhi S, Kupersmith E, Cerceo E. Impact of Length of Stay on Readmission in Hospitalized Patients. Cureus. 2020;12(9):e10669. Published 2020 Sep 26. doi:10.7759/cureus.10669
#
#
# ################################################################################

# %%
print('Health Data Science Workflow: 8')
print('This step is to interprete the model with SHAP package.')
# Python code here (10 lines limit, and 2 cells limit)
# scale the features
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
# Aquire the best model from the grid search 
optimized_RF = grid_search_RF.best_estimator_
# Train and calculate the SHAP value
explainer_RF = shap.TreeExplainer(optimized_RF[1], X_train_scaled, feature_perturbation = "interventional")
shap_values_Model_train = explainer_RF.shap_values(X_train_scaled, check_additivity=False)
# Out:
# Health Data Science Workflow: 8
# This step is to interprete the model with SHAP package.
# 100%|===================| 110806/110826 [36:11<00:00]

# %%
# Summary plot - SHAP
shap.initjs()
shap.summary_plot(shap_values_Model_train, X_train, 
                   feature_names= X_train.columns,max_display=10)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
# Python code here (10 lines limit, and 2 cells limit)

# Aquire the best model from the grid search 
optimized_RF = grid_search_RF.best_estimator_
# Train and calculate the SHAP value
explainer_RF = shap.TreeExplainer(optimized_RF[1], X_train, feature_perturbation = "interventional")
shap_values_Model_train = explainer_RF.shap_values(X_train, check_additivity=False)
# Out:
# 100%|===================| 110613/110826 [08:03<00:00]

# %% [markdown]
# ---

# %% [markdown]
# © 2022 Copyright The University of New South Wales - CRICOS 00098G
